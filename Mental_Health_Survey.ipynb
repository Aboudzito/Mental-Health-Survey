# %% [markdown]
# <a href="https://colab.research.google.com/github/Aboudzito/Mental-Health-Survey/blob/main/Mental_Health_Survey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('/content/Mental Health Survey (Responses) - Form responses 1.csv')

# %%
df.head()
# Out:
#    Timestamp What is your class?     s  \
# 0  Excellent                 Yes  Good
# 1  Excellent                 Yes  Good
# 2       Good            Somewhat  Good
# 3  Excellent                 Yes  Good
# 4  Excellent                 Yes  Good
#
#   I understand why mental health is important in daily life.  \
# 0                                              Agree
# 1                                              Agree
# 2                                              Agree
# 3                                     Strongly agree
# 4                                              Agree
#
#   I can identify common mental health challenges.  \
# 0                                           Maybe
# 1                                             Yes
# 2                                             Yes
# 3                                             Yes
# 4                                             Yes
#
#   I learned practical startegies to manage stress and emotions.  \
# ...

# %%
df = df.drop(index=range(12))
display(df.head())
# Out:
#               Timestamp What is your class?      s  \
# 12  19/11/2025 09:44:54                  3C    Yes
# 13  19/11/2025 09:44:59                  3G  Maybe
# 14  19/11/2025 09:45:07                  3J    Yes
# 15  19/11/2025 09:45:08                  3I    Yes
# 16  19/11/2025 09:45:42                  3C    Yes
#
#    I understand why mental health is important in daily life.  \
# 12                                              Agree
# 13                                              Agree
# 14                                     Strongly agree
# 15                                     Strongly agree
# 16                                     Strongly agree
#
#    I can identify common mental health challenges.  \
# 12                                             Yes
# 13                                             Yes
# 14                                             Yes
# 15                                             Yes
# 16                                             Yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 12 to 135
# Data columns (total 14 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Timestamp                                                        124 non-null    object
#  1   What is your class?                                              124 non-null    object
#  2   s                                                                124 non-null    object
#  3   I understand why mental health is important in daily life.       124 non-null    object
#  4   I can identify common mental health challenges.                  124 non-null    object
#  5   I learned practical startegies to manage stress and emotions.    124 non-null    object
#  6   I can apply one strategy discussed.                              124 non-null    object
# ...

# %%
df.describe()
# Out:
#                   Timestamp What is your class?    s  \
# count                   124                 124  124
# unique                  115                  14    3
# top     19/11/2025 09:46:27                  3H  Yes
# freq                      2                  19  119
#
#        I understand why mental health is important in daily life.  \
# count                                                 124
# unique                                                  3
# top                                        Strongly agree
# freq                                                   77
#
#        I can identify common mental health challenges.  \
# count                                              124
# unique                                               3
# top                                                Yes
# freq                                                96
#
#        I learned practical startegies to manage stress and emotions.  \
# ...

# %%
df = df.drop(columns='Timestamp')
display(df.head())
# Out:
#    What is your class?      s  \
# 12                  3C    Yes
# 13                  3G  Maybe
# 14                  3J    Yes
# 15                  3I    Yes
# 16                  3C    Yes
#
#    I understand why mental health is important in daily life.  \
# 12                                              Agree
# 13                                              Agree
# 14                                     Strongly agree
# 15                                     Strongly agree
# 16                                     Strongly agree
#
#    I can identify common mental health challenges.  \
# 12                                             Yes
# 13                                             Yes
# 14                                             Yes
# 15                                             Yes
# 16                                             Yes
#
#    I learned practical startegies to manage stress and emotions.  \
# 12                                       Very helpful
# ...

# %%
df = df.drop(columns='Any recommendations for the session?')
display(df.head())
# Out:
#    What is your class?      s  \
# 12                  3C    Yes
# 13                  3G  Maybe
# 14                  3J    Yes
# 15                  3I    Yes
# 16                  3C    Yes
#
#    I understand why mental health is important in daily life.  \
# 12                                              Agree
# 13                                              Agree
# 14                                     Strongly agree
# 15                                     Strongly agree
# 16                                     Strongly agree
#
#    I can identify common mental health challenges.  \
# 12                                             Yes
# 13                                             Yes
# 14                                             Yes
# 15                                             Yes
# 16                                             Yes
#
#    I learned practical startegies to manage stress and emotions.  \
# 12                                       Very helpful
# ...

# %%
df.drop_duplicates(inplace = True)

# %%
df.describe()
# Out:
#        What is your class?    s  \
# count                  121  121
# unique                  14    3
# top                     3H  Yes
# freq                    19  116
#
#        I understand why mental health is important in daily life.  \
# count                                                 121
# unique                                                  3
# top                                        Strongly agree
# freq                                                   74
#
#        I can identify common mental health challenges.  \
# count                                              121
# unique                                               3
# top                                                Yes
# freq                                                93
#
#        I learned practical startegies to manage stress and emotions.  \
# count                                                 121
# unique                                                  3
# ...

# %%
label_encoder = LabelEncoder()

for column in df.select_dtypes(include='object').columns:
    df[column] = label_encoder.fit_transform(df[column])

df.head()
# Out:
#     What is your class?  s  \
# 12                    4  2
# 13                    9  0
# 14                   12  2
# 15                   11  2
# 16                    4  2
#
#     I understand why mental health is important in daily life.  \
# 12                                                  0
# 13                                                  0
# 14                                                  2
# 15                                                  2
# 16                                                  2
#
#     I can identify common mental health challenges.  \
# 12                                                2
# 13                                                2
# 14                                                2
# 15                                                2
# 16                                                2
#
#     I learned practical startegies to manage stress and emotions.  \
# 12                                                  2
# ...

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Encoded Features')
plt.show()

# %%
import pandas as pd

# Grouping by class and calculating the mean for understanding
# Note: Since LabelEncoder was used, we need to look at the distribution
# or identify the original mapping to be precise.

understanding_col = 'I understand why mental health is important in daily life.'
class_col = 'What is your class?'

# Calculate mean understanding per class
class_performance = df.groupby(class_col)[understanding_col].mean().sort_values()

print("Mean understanding score per class (Encoded values):")
print(class_performance)

# To provide a better answer, let's look at the counts of 'Strongly agree' (which likely became a specific encoded value)
print("\nDistribution of responses per class:")
pivot_table = pd.crosstab(df[class_col], df[understanding_col])
display(pivot_table)
# Out:
# Mean understanding score per class (Encoded values):
# What is your class?
# 13    0.800000
# 11    0.909091
# 0     1.000000
# 12    1.000000
# 10    1.105263
# 6     1.111111
# 7     1.200000
# 4     1.222222
# 1     1.300000
# 9     1.444444
# 5     1.500000
# 8     1.500000
# 3     1.750000
# 2     2.000000
# Name: I understand why mental health is important in daily life., dtype: float64
#
# Distribution of responses per class:
# I understand why mental health is important in daily life.  0  1   2
# What is your class?
# 0                                                           3  0   3
# 1                                                           3  1   6
# 2                                                           0  0   7
# 3                                                           1  0   7
# 4                                                           3  1   5
# 5                                                           2  0   6
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=pivot_table)
# Out:
# https://docs.google.com/spreadsheets/d/16ZCvURV2BDl0YsDA2tLOC4IolEzyg72E0qS7VupDTh0/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/16ZCvURV2BDl0YsDA2tLOC4IolEzyg72E0qS7VupDTh0/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Define features (X) and target (y)
# 'Did you understand from this teacher' is a good binary target (0 or 1 after label encoding)
X = df.drop('The session helped clear misunderstandings about mental health.', axis=1)
y = df['The session helped clear misunderstandings about mental health.']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train the Logistic Regression model
model = LogisticRegression(max_iter=200) # Increased max_iter for convergence
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6756756756756757
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.69      0.64      0.67        14
#            2       0.25      0.20      0.22         5
#            3       0.75      0.83      0.79        18
#
#     accuracy                           0.68        37
#    macro avg       0.56      0.56      0.56        37
# weighted avg       0.66      0.68      0.67        37

# %%
importance = np.mean(np.abs(model.coef_), axis=0)
feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': importance})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)

print("Top factors influencing whether misunderstandings were cleared:")
display(feature_importance)
# Out:
# Top factors influencing whether misunderstandings were cleared:
#                                               Feature  Importance
# 10  I felt comfortable and respected during the se...    0.668211
# 9             Overall, the presenters did a good job.    0.651451
# 8       The presenters explained the content clearly.    0.589603
# 1                                                   s    0.575675
# 4   I learned practical startegies to manage stres...    0.553679
# 2   I understand why mental health is important in...    0.249303
# 6   The session helped clear misunderstandings abo...    0.203553
# 0                                 What is your class?    0.162047
# 5                 I can apply one strategy discussed.    0.130117
# 7   I know where and whom to ask for help if I'm s...    0.097819
# 3     I can identify common mental health challenges.    0.080378

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %%
X = df.drop('The presenters kept the session engaging', axis=1)
y = df['The presenters kept the session engaging']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
model = LogisticRegression(max_iter=200)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.8108108108108109
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.60      0.38      0.46         8
#            2       0.84      0.93      0.89        29
#
#     accuracy                           0.81        37
#    macro avg       0.72      0.65      0.67        37
# weighted avg       0.79      0.81      0.79        37
